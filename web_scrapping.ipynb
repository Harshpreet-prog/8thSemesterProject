# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshpreet-prog/8thSemesterProject/blob/main/web_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.amazon.{country}/dp/{asin}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

ls = pd.read_csv("/content/drive/MyDrive/Amazon Scraping - Sheet1.csv")
ls.drop("id",axis = 1,inplace = True)
ls
# Out:
#      Unnamed: 0        Asin country
# 0             0        1015      de
# 1             1        1015      fr
# 2             2  000004458X      de
# 3             3  000004458X      fr
# 4             4     1002198      de
# ..          ...         ...     ...
# 995         995     4484924      fr
# 996         996     4485742      de
# 997         997     4485742      fr
# 998         998     4486072      de
# 999         999     4486072      fr
#
# [1000 rows x 3 columns]

# %%
import time
import pandas as pd
from bs4 import BeautifulSoup
from requests_html import HTMLSession
import json

s = HTMLSession()

def get_data(url):
    webpage = s.get(url)
    soup = BeautifulSoup(webpage.content, "html.parser")
    try:
       product_title = soup.find("span",attrs={"id": 'productTitle'}).text
    
    except AttributeError:
      return "file not found"
    
    try:
       product_image_url =soup.find("img",{"alt": ""})['src']
   
    except AttributeError:

       return "file not found"
   
    try:

       product_price = (soup.find("span", class_="a-color-base").text)

    except AttributeError:

      return "file not found"
   
    try:
       product_details = []
       details = soup.findAll("span", {"class":"a-list-item"})
       for tags in details:
         value = tags.text.replace("\n", "")
         product_details.append("".join(value))

    except AttributeError:
      return "file not found"
   
    
    return [{"product_title" : product_title ,"product_image_url": product_image_url,"product_price" : product_price,
            "product_details": product_details}] 

def save_data(collectedData):
  with open('dataCollected.json', 'w') as myfile:
    try:
      json.dump(collectedData,myfile)
      print(collectedData)
    except TypeError:
      print("cant dump")
    

def main():
    start_time = time.time()
    print("saving the output of extracted information")
    url1 ="https://www.amazon."
    url2 = "/dp/"
    new_file = ls[["Asin","country"]]

    for index,row in new_file.iterrows():
        url = url1 + row["country"] + url2 + row["Asin"]
        #print(url)
        data =  get_data(url)
        save_data(data)
 
        #web scrapinf code here  
    
    time_diffrence = time.time() - start_time
    print("scrapping time: %2f secondfs" %time_diffrence)
     
main()
# Out:
# saving the output of extracted information
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# file not found
# ...
